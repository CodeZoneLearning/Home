# %% [markdown]
# # Consistência dos testes de equipamento
#
# O notebook registra a pergunta e usa a regra estável do módulo `equipment_summary.py`.

# %%
from equipment_summary import summarize

# %%
tests = [
    {"status": 2, "confidence": 0.91},
    {"status": 2, "confidence": 0.88},
    {"status": 3, "confidence": 0.62},
]
summary = summarize(tests)
summary

# %% [markdown]
# ## Leitura
#
# A classe modal é 2, mas os testes não são totalmente consistentes. O próximo passo é investigar o teste que retornou classe 3.
